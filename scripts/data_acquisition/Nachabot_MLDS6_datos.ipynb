# %% [markdown]
# # Nachabot - Clasificador de texto con respecto al proceso de admisión a la Universidad Nacional de Colombia

# %% [markdown]
# ## Conjunto de datos

# %% [markdown]
# Conectar con Google drive

# %%
from google.colab import drive
import pandas as pd

# Montar Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# El archivo que usaremos para los datos será un excel llamado nachabot-dataset.xlsx basado en la información almacenada en la Dirección Nacional de Admisiones el cual presenta información relevante para el proceso de admisión de la Universidad Nacional de Colombia para los precesos de pregrado y posgrado. Este conjunto de datos tiene un par de pregunta y respuesta, un identificador de respuesta y un identificador de tema.

# %%
import pandas as pd

path_to_dataset = '/content/drive/MyDrive/Colab Notebooks/nachabot-dataset.xlsx'

data = pd.read_excel(path_to_dataset)
data
# Out:
#                                               pregunta  \
# 0             ¿Cuando comienza el proceso de admisión?
# 1            ¿Hasta cuando tengo plazo de inscribirme?
# 2           ¿A qué horas se cierran las inscripciones?
# 3                        ¿Cuando puedo comprar el pin?
# 4    ¿Cuando puedo comprar los derechos de inscripc...
# ..                                                 ...
# 395  Pagué los derechos de inscripción para una con...
# 396  Hice el pago virtual de los derechos de inscri...
# 397  Hice el pago virtual más de una vez por error ...
# 398  Pagué los derechos de inscripción para una con...
# 399  Tengo incapacidad médica y no podré realizar e...
#
#                                              respuesta  respuesta_id  tema_id
# 0    Podrá consultar esa información en la página w...             0        1
# 1    Podrá consultar esa información en la página w...             0        1
# ...
